# %% [markdown]
# # Estadísticos principales
#
# En estas notas se anotara sobre los principales estadisticos

# %% [markdown]
# -----
#
# ## Experimento
#
# Procedimiento que puede repetirse infinitamente y tiene un conjunto bien definido de resultados posbiles, conocido como espacio muestral
#
# - **Aleatorio**: si tiene más de un resultado posible
# - **Determinista**: si solo tiene un resultado posible

# %% [markdown]
# -----
#
# ## Población y muestra
#
# **Muestra**: subconjunto de datos perteneciente a una población
#
# Condiciones:
# - **Número** suficiente de registros para ser estadísticamente significativo.
# - Representación no segasda de la información total.
#
# ![Muestra y población](data:image/png;base64,...)

# %% [markdown]
# -----
#
# ## Evento
#
# Cada uno de los posibles resultados de un experimento
#
# -----
#
# ## Variables
#
# Es una caracteristica que puede obtener diferentes valores
#
# Tipos:
#
# - Cualitativos: atributos (no medibles)
# - Cuantitavitos: números
#     - Discretas
#     - Continuas
#
# -----
#
# ## Probabilidad
#
# Mide **que tan posible** es que ocurra un evento determinado
#
# El análisis de los eventos probabilisticos se denomina **estadística**
#
# -----
#
# ## Probabilidad Condicionada
#
# Posibilidad de que ocurra un evento como consecuencia de que otro evento haya sucedido
#
# $$
# P(A|B) = \frac{P(A \cap B)}{P(B)}
# $$
#
# ![Probabilidad condicionada](https://www.fhybea.com/herramientas/imagenes_articulos/probabilidad-condicional/probabilidad-condicional.png)

# %% [markdown]
# -----
#
# # Población normal
#
# - Distribución normal = Distribución de Gauss
# - Su moda = Su media = Su mediana
# - Es símetrica
# - Tiene forma de campana
#
# ![distribución normal](https://economipedia.com/wp-content/uploads/Captura-de-pantalla-2019-09-10-a-les-11.09.35.png)
#
# ## Ejemplos de población normal
#
# - Calorias ingeridas y peso
# - Presión sanguinea
# - Tamaño de los coches podrucidos en una linea de producción

# %% [markdown]
# -----
#
# # Introducción al muestreo y teorema del límite central
#
# ## Muestreo
#
# - Técnica para la selección de una muestra
# - Se obtiene a partir de una población estadística
# - La selección tiene que ser aleatoria y se espera que sus propiedades seaan extrapolables a la población
#
# -----
#
# ## Tipos de muestro
#
# - Aleatorio simple
# - Sistematico
# - Estratificado
#
# -----
#
# ## Teorema del límite central
#
# Teoría estadística que establece que, dada una muestra aleatoria lo suficientemente grande de la poblacion, la distribución de las medias seguirá una distribución normal
